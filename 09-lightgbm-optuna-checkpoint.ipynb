# %% [markdown]
# # 데모

# %% [markdown]
# ## 라이브러리 import 및 설정

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from lightgbm import LGBMClassifier
from matplotlib import pyplot as plt
from matplotlib import rcParams
import numpy as np
import optuna.integration.lightgbm as lgb
from pathlib import Path
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split
import seaborn as sns
import warnings

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
pd.set_option('max_columns', 100)
pd.set_option("display.precision", 4)
warnings.simplefilter('ignore')

# %% [markdown]
# ## 학습데이터 로드

# %% [markdown]
# [03-pandas-eda.ipynb](https://github.com/kaggler-tv/dku-kaggle-class/blob/master/notebook/03-pandas-eda.ipynb)에서 생성한 `feature.csv` 피처파일 사용

# %%
data_dir = Path('./DACON')
feature_dir = Path('./DACON_feature')
val_dir = Path('./DACON_val')
tst_dir = Path('./DACON_tst')
sub_dir = Path('./DACON_sub')

trn_file = data_dir / 'train.csv'
tst_file = data_dir / 'test.csv'
sample_file = data_dir / 'sample_submission.csv'

target_col = 'class'
n_fold = 5
n_class = 3
seed = 42

# %%
algo_name = 'lgb_optuna'
feature_name = 'feature'
model_name = f'{algo_name}_{feature_name}'

feature_file = feature_dir / f'{feature_name}.csv'
p_val_file = val_dir / f'{model_name}.val.csv'
p_tst_file = tst_dir / f'{model_name}.tst.csv'
sub_file = sub_dir / f'{model_name}.csv'

# %%
df = pd.read_csv(feature_file, index_col=0)
print(df.shape)
df.head()
# Out:
# (400000, 20)
#           z    redshift  dered_u  dered_g  dered_r  dered_i  dered_z  \
# id
# 0   16.9396 -8.1086e-05  23.1243  20.2578  18.9551  17.6321  16.9089
# 1   13.1689  4.5061e-03  14.9664  14.0045  13.4114  13.2363  13.1347
# 2   15.3500  4.7198e-04  16.6076  15.6866  15.4400  15.3217  15.2961
# 3   19.6346  5.8143e-06  25.3536  20.9947  20.0873  19.7947  19.5552
# 4   17.9826 -3.3247e-05  23.7714  20.4338  18.8630  18.1903  17.8759
#
#     nObserve  airmass_u  class  d_dered_u  d_dered_g  d_dered_r  d_dered_i  \
# id
# 0     2.9444     1.1898    0.0    -0.1397    -0.0790    -0.0544    -0.0403
# 1     0.6931     1.2533    1.0    -0.0857    -0.0574    -0.0410    -0.0322
# 2     1.0986     1.0225    0.0    -0.1787    -0.1388    -0.0963    -0.0718
# 3     1.6094     1.2054    0.0    -0.3070    -0.1941    -0.1339    -0.1003
# 4     2.6391     1.1939    0.0    -0.6820    -0.2653    -0.1794    -0.1339
#
#     d_dered_z  d_dered_ig  d_dered_zg  d_dered_rz  d_dered_iz  d_obs_det
# id
# 0     -0.0307     -2.6257     -3.3488      2.0462      0.7232   -15.0556
# 1     -0.0343     -0.7683     -0.8698      0.2767      0.1016    -0.3069
# 2     -0.0540     -0.3649     -0.3905      0.1440      0.0257    -0.9014
# 3     -0.0795     -1.2000     -1.4395      0.5321      0.2395    -1.3906
# 4     -0.1067     -2.2436     -2.5579      0.9871      0.3144    -9.3609

# %%
y = df[target_col].values[:320000]
df.drop(target_col, axis=1, inplace=True)
trn = df.iloc[:320000].values
tst = df.iloc[320000:].values
feature_name = df.columns.tolist()
print(y.shape, trn.shape, tst.shape)
# Out:
# (320000,) (320000, 19) (80000, 19)

# %% [markdown]
# ## Hyperparameter Tuning

# %%
X_trn, X_val, y_trn, y_val = train_test_split(trn, y, test_size=.2, random_state=seed)

# %%
params = {
    "objective": "multiclass",
    "metric": "multi_logloss",
    "num_class": 3,
    "n_estimators": 1000,
    "subsample_freq": 1,
    "lambda_l1": 0.,
    "lambda_l2": 0.,
    "random_state": seed,
    "n_jobs": -1,
}

# %%
dtrain = lgb.Dataset(X_trn, label=y_trn)
dval = lgb.Dataset(X_val, label=y_val)

model = lgb.train(params, dtrain, valid_sets=[dtrain, dval], 
                  verbose_eval=100, early_stopping_rounds=10)

prediction = np.argmax(model.predict(X_val, num_iteration=model.best_iteration), 
                       axis=1)
accuracy = accuracy_score(y_val, prediction)

params = model.params
print("Best params:", params)
print("  Accuracy = {}".format(accuracy))
print("  Params: ")
for key, value in params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2020-10-07 00:02:31,046] A new study created in memory with name: no-name-f148b374-d495-458f-b179-a77f0f5bece1
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023852 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [84]	training's multi_logloss: 0.157951	valid_1's multi_logloss: 0.171065
# feature_fraction, val_score: 0.171065:  14%|#4        | 1/7 [00:04<00:29,  4.97s/it][I 2020-10-07 00:02:36,026] Trial 0 finished with value: 0.17106546374660533 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.17106546374660533.
# feature_fraction, val_score: 0.171065:  14%|#4        | 1/7 [00:04<00:29,  4.97s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032394 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.154537	valid_1's multi_logloss: 0.168848
# Early stopping, best iteration is:
# [100]	training's multi_logloss: 0.154537	valid_1's multi_logloss: 0.168848
# feature_fraction, val_score: 0.168848:  29%|##8       | 2/7 [00:09<00:24,  4.96s/it][I 2020-10-07 00:02:40,968] Trial 1 finished with value: 0.16884814405994308 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 1 with value: 0.16884814405994308.
# feature_fraction, val_score: 0.168848:  29%|##8       | 2/7 [00:09<00:24,  4.96s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032978 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.157561	valid_1's multi_logloss: 0.171575
# [200]	training's multi_logloss: 0.142331	valid_1's multi_logloss: 0.167124
# [300]	training's multi_logloss: 0.132451	valid_1's multi_logloss: 0.165539
# Early stopping, best iteration is:
# [339]	training's multi_logloss: 0.129184	valid_1's multi_logloss: 0.1652
# feature_fraction, val_score: 0.165200:  43%|####2     | 3/7 [00:23<00:29,  7.48s/it][I 2020-10-07 00:02:54,314] Trial 2 finished with value: 0.1652001900792115 and parameters: {'feature_fraction': 0.6}. Best is trial 2 with value: 0.1652001900792115.
# feature_fraction, val_score: 0.165200:  43%|####2     | 3/7 [00:23<00:29,  7.48s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032976 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [84]	training's multi_logloss: 0.15888	valid_1's multi_logloss: 0.17079
# feature_fraction, val_score: 0.165200:  57%|#####7    | 4/7 [00:27<00:19,  6.41s/it][I 2020-10-07 00:02:58,236] Trial 3 finished with value: 0.17079019626091355 and parameters: {'feature_fraction': 0.8}. Best is trial 2 with value: 0.1652001900792115.
# feature_fraction, val_score: 0.165200:  57%|#####7    | 4/7 [00:27<00:19,  6.41s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023530 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.162635	valid_1's multi_logloss: 0.174495
# [200]	training's multi_logloss: 0.145415	valid_1's multi_logloss: 0.167222
# [300]	training's multi_logloss: 0.135503	valid_1's multi_logloss: 0.165288
# [400]	training's multi_logloss: 0.127805	valid_1's multi_logloss: 0.164431
# [500]	training's multi_logloss: 0.121098	valid_1's multi_logloss: 0.163906
# Early stopping, best iteration is:
# [492]	training's multi_logloss: 0.121624	valid_1's multi_logloss: 0.163897
# feature_fraction, val_score: 0.163897:  71%|#######1  | 5/7 [00:46<00:20, 10.20s/it][I 2020-10-07 00:03:17,265] Trial 4 finished with value: 0.16389663869951765 and parameters: {'feature_fraction': 0.4}. Best is trial 4 with value: 0.16389663869951765.
# feature_fraction, val_score: 0.163897:  71%|#######1  | 5/7 [00:46<00:20, 10.20s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030245 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.158738	valid_1's multi_logloss: 0.171262
# [200]	training's multi_logloss: 0.143196	valid_1's multi_logloss: 0.16598
# [300]	training's multi_logloss: 0.133309	valid_1's multi_logloss: 0.164397
# [400]	training's multi_logloss: 0.125445	valid_1's multi_logloss: 0.163806
# Early stopping, best iteration is:
# [390]	training's multi_logloss: 0.126127	valid_1's multi_logloss: 0.163804
# feature_fraction, val_score: 0.163804:  86%|########5 | 6/7 [01:02<00:12, 12.03s/it][I 2020-10-07 00:03:33,577] Trial 5 finished with value: 0.16380353002543135 and parameters: {'feature_fraction': 0.5}. Best is trial 5 with value: 0.16380353002543135.
# feature_fraction, val_score: 0.163804:  86%|########5 | 6/7 [01:02<00:12, 12.03s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032732 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.155816	valid_1's multi_logloss: 0.16912
# Early stopping, best iteration is:
# [107]	training's multi_logloss: 0.154442	valid_1's multi_logloss: 0.168604
# feature_fraction, val_score: 0.163804: 100%|##########| 7/7 [01:08<00:00, 10.12s/it][I 2020-10-07 00:03:39,255] Trial 6 finished with value: 0.16860373848230312 and parameters: {'feature_fraction': 0.7}. Best is trial 5 with value: 0.16380353002543135.
# feature_fraction, val_score: 0.163804: 100%|##########| 7/7 [01:08<00:00,  9.74s/it]
# num_leaves, val_score: 0.163804:   0%|          | 0/20 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030272 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.120687	valid_1's multi_logloss: 0.164017
# Early stopping, best iteration is:
# [139]	training's multi_logloss: 0.108658	valid_1's multi_logloss: 0.163359
# num_leaves, val_score: 0.163359:   5%|5         | 1/20 [00:09<02:56,  9.26s/it][I 2020-10-07 00:03:48,528] Trial 7 finished with value: 0.16335945338404878 and parameters: {'num_leaves': 144}. Best is trial 7 with value: 0.16335945338404878.
# num_leaves, val_score: 0.163359:   5%|5         | 1/20 [00:09<02:56,  9.26s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002900 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.142833	valid_1's multi_logloss: 0.166161
# Early stopping, best iteration is:
# [182]	training's multi_logloss: 0.126186	valid_1's multi_logloss: 0.163676
# num_leaves, val_score: 0.163359:  10%|#         | 2/20 [00:20<02:58,  9.91s/it][I 2020-10-07 00:03:59,959] Trial 8 finished with value: 0.1636759032998907 and parameters: {'num_leaves': 65}. Best is trial 7 with value: 0.16335945338404878.
# num_leaves, val_score: 0.163359:  10%|#         | 2/20 [00:20<02:58,  9.91s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003868 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.143493	valid_1's multi_logloss: 0.166365
# [200]	training's multi_logloss: 0.124109	valid_1's multi_logloss: 0.16381
# Early stopping, best iteration is:
# [219]	training's multi_logloss: 0.121284	valid_1's multi_logloss: 0.163512
# num_leaves, val_score: 0.163359:  15%|#5        | 3/20 [00:34<03:09, 11.12s/it][I 2020-10-07 00:04:13,907] Trial 9 finished with value: 0.16351179761158707 and parameters: {'num_leaves': 63}. Best is trial 7 with value: 0.16335945338404878.
# num_leaves, val_score: 0.163359:  15%|#5        | 3/20 [00:34<03:09, 11.12s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030221 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.101285	valid_1's multi_logloss: 0.162928
# Early stopping, best iteration is:
# [119]	training's multi_logloss: 0.0935193	valid_1's multi_logloss: 0.162697
# num_leaves, val_score: 0.162697:  20%|##        | 4/20 [00:44<02:51, 10.72s/it][I 2020-10-07 00:04:23,685] Trial 10 finished with value: 0.16269677134075733 and parameters: {'num_leaves': 240}. Best is trial 10 with value: 0.16269677134075733.
# num_leaves, val_score: 0.162697:  20%|##        | 4/20 [00:44<02:51, 10.72s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002644 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.104908	valid_1's multi_logloss: 0.163131
# Early stopping, best iteration is:
# [108]	training's multi_logloss: 0.101645	valid_1's multi_logloss: 0.163073
# num_leaves, val_score: 0.162697:  25%|##5       | 5/20 [00:55<02:40, 10.69s/it][I 2020-10-07 00:04:34,308] Trial 11 finished with value: 0.1630734652176996 and parameters: {'num_leaves': 220}. Best is trial 10 with value: 0.16269677134075733.
# num_leaves, val_score: 0.162697:  25%|##5       | 5/20 [00:55<02:40, 10.69s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003324 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.09912	valid_1's multi_logloss: 0.16292
# Early stopping, best iteration is:
# [112]	training's multi_logloss: 0.0939759	valid_1's multi_logloss: 0.162729
# num_leaves, val_score: 0.162697:  30%|###       | 6/20 [01:06<02:34, 11.02s/it][I 2020-10-07 00:04:46,103] Trial 12 finished with value: 0.1627285982640051 and parameters: {'num_leaves': 254}. Best is trial 10 with value: 0.16269677134075733.
# num_leaves, val_score: 0.162697:  30%|###       | 6/20 [01:06<02:34, 11.02s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022469 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.098643	valid_1's multi_logloss: 0.163196
# Early stopping, best iteration is:
# [110]	training's multi_logloss: 0.0941575	valid_1's multi_logloss: 0.162966
# num_leaves, val_score: 0.162697:  35%|###5      | 7/20 [01:16<02:18, 10.67s/it][I 2020-10-07 00:04:55,955] Trial 13 finished with value: 0.16296599909980072 and parameters: {'num_leaves': 256}. Best is trial 10 with value: 0.16269677134075733.
# num_leaves, val_score: 0.162697:  35%|###5      | 7/20 [01:16<02:18, 10.67s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.108615	valid_1's multi_logloss: 0.163105
# Early stopping, best iteration is:
# [124]	training's multi_logloss: 0.0993416	valid_1's multi_logloss: 0.162864
# num_leaves, val_score: 0.162697:  40%|####      | 8/20 [01:27<02:08, 10.73s/it][I 2020-10-07 00:05:06,820] Trial 14 finished with value: 0.16286424977976174 and parameters: {'num_leaves': 201}. Best is trial 10 with value: 0.16269677134075733.
# num_leaves, val_score: 0.162697:  40%|####      | 8/20 [01:27<02:08, 10.73s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024541 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.0991437	valid_1's multi_logloss: 0.163
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.0952678	valid_1's multi_logloss: 0.162922
# num_leaves, val_score: 0.162697:  45%|####5     | 9/20 [01:38<01:58, 10.76s/it][I 2020-10-07 00:05:17,649] Trial 15 finished with value: 0.16292165761055885 and parameters: {'num_leaves': 253}. Best is trial 10 with value: 0.16269677134075733.
# num_leaves, val_score: 0.162697:  45%|####5     | 9/20 [01:38<01:58, 10.76s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026387 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.114009	valid_1's multi_logloss: 0.163343
# Early stopping, best iteration is:
# [119]	training's multi_logloss: 0.107067	valid_1's multi_logloss: 0.16315
# num_leaves, val_score: 0.162697:  50%|#####     | 10/20 [01:48<01:44, 10.42s/it][I 2020-10-07 00:05:27,276] Trial 16 finished with value: 0.16314991062330608 and parameters: {'num_leaves': 173}. Best is trial 10 with value: 0.16269677134075733.
# num_leaves, val_score: 0.162697:  50%|#####     | 10/20 [01:48<01:44, 10.42s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002909 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.0989048	valid_1's multi_logloss: 0.162904
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.0949343	valid_1's multi_logloss: 0.162627
# num_leaves, val_score: 0.162627:  55%|#####5    | 11/20 [02:00<01:38, 10.91s/it][I 2020-10-07 00:05:39,326] Trial 17 finished with value: 0.16262675322815182 and parameters: {'num_leaves': 255}. Best is trial 17 with value: 0.16262675322815182.
# num_leaves, val_score: 0.162627:  55%|#####5    | 11/20 [02:00<01:38, 10.91s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002740 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.106478	valid_1's multi_logloss: 0.16283
# Early stopping, best iteration is:
# [106]	training's multi_logloss: 0.103951	valid_1's multi_logloss: 0.16259
# num_leaves, val_score: 0.162590:  60%|######    | 12/20 [02:10<01:27, 10.88s/it][I 2020-10-07 00:05:50,155] Trial 18 finished with value: 0.16258979328295248 and parameters: {'num_leaves': 211}. Best is trial 18 with value: 0.16258979328295248.
# num_leaves, val_score: 0.162590:  60%|######    | 12/20 [02:10<01:27, 10.88s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.111736	valid_1's multi_logloss: 0.163183
# Early stopping, best iteration is:
# [127]	training's multi_logloss: 0.101708	valid_1's multi_logloss: 0.162805
# num_leaves, val_score: 0.162590:  65%|######5   | 13/20 [02:21<01:16, 10.87s/it][I 2020-10-07 00:06:00,981] Trial 19 finished with value: 0.16280522495478336 and parameters: {'num_leaves': 185}. Best is trial 18 with value: 0.16258979328295248.
# num_leaves, val_score: 0.162590:  65%|######5   | 13/20 [02:21<01:16, 10.87s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025552 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.129518	valid_1's multi_logloss: 0.164517
# Early stopping, best iteration is:
# [143]	training's multi_logloss: 0.117473	valid_1's multi_logloss: 0.163367
# num_leaves, val_score: 0.162590:  70%|#######   | 14/20 [02:32<01:04, 10.78s/it][I 2020-10-07 00:06:11,556] Trial 20 finished with value: 0.16336707241182985 and parameters: {'num_leaves': 109}. Best is trial 18 with value: 0.16258979328295248.
# num_leaves, val_score: 0.162590:  70%|#######   | 14/20 [02:32<01:04, 10.78s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024326 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.103973	valid_1's multi_logloss: 0.163202
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.100268	valid_1's multi_logloss: 0.163015
# num_leaves, val_score: 0.162590:  75%|#######5  | 15/20 [02:42<00:52, 10.57s/it][I 2020-10-07 00:06:21,647] Trial 21 finished with value: 0.16301457730406466 and parameters: {'num_leaves': 225}. Best is trial 18 with value: 0.16258979328295248.
# num_leaves, val_score: 0.162590:  75%|#######5  | 15/20 [02:42<00:52, 10.57s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027671 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.098643	valid_1's multi_logloss: 0.163196
# Early stopping, best iteration is:
# [110]	training's multi_logloss: 0.0941575	valid_1's multi_logloss: 0.162966
# num_leaves, val_score: 0.162590:  80%|########  | 16/20 [02:52<00:42, 10.55s/it][I 2020-10-07 00:06:32,159] Trial 22 finished with value: 0.16296599909980072 and parameters: {'num_leaves': 256}. Best is trial 18 with value: 0.16258979328295248.
# num_leaves, val_score: 0.162590:  80%|########  | 16/20 [02:52<00:42, 10.55s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023934 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.104401	valid_1's multi_logloss: 0.163092
# Early stopping, best iteration is:
# [123]	training's multi_logloss: 0.0954235	valid_1's multi_logloss: 0.162958
# num_leaves, val_score: 0.162590:  85%|########5 | 17/20 [03:03<00:31, 10.62s/it][I 2020-10-07 00:06:42,927] Trial 23 finished with value: 0.16295829282341548 and parameters: {'num_leaves': 223}. Best is trial 18 with value: 0.16258979328295248.
# num_leaves, val_score: 0.162590:  85%|########5 | 17/20 [03:03<00:31, 10.62s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.103673	valid_1's multi_logloss: 0.162714
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.0998601	valid_1's multi_logloss: 0.162542
# num_leaves, val_score: 0.162542:  90%|######### | 18/20 [03:13<00:20, 10.46s/it][I 2020-10-07 00:06:53,008] Trial 24 finished with value: 0.16254197131599904 and parameters: {'num_leaves': 228}. Best is trial 24 with value: 0.16254197131599904.
# num_leaves, val_score: 0.162542:  90%|######### | 18/20 [03:13<00:20, 10.46s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003080 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.118253	valid_1's multi_logloss: 0.163669
# Early stopping, best iteration is:
# [124]	training's multi_logloss: 0.109931	valid_1's multi_logloss: 0.162935
# num_leaves, val_score: 0.162542:  95%|#########5| 19/20 [03:24<00:10, 10.62s/it][I 2020-10-07 00:07:03,994] Trial 25 finished with value: 0.16293541251215335 and parameters: {'num_leaves': 154}. Best is trial 24 with value: 0.16254197131599904.
# num_leaves, val_score: 0.162542:  95%|#########5| 19/20 [03:24<00:10, 10.62s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023420 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.208544	valid_1's multi_logloss: 0.211315
# [200]	training's multi_logloss: 0.188205	valid_1's multi_logloss: 0.19262
# [300]	training's multi_logloss: 0.178227	valid_1's multi_logloss: 0.184104
# [400]	training's multi_logloss: 0.172049	valid_1's multi_logloss: 0.179282
# Early stopping, best iteration is:
# [468]	training's multi_logloss: 0.168844	valid_1's multi_logloss: 0.176836
# num_leaves, val_score: 0.162542: 100%|##########| 20/20 [03:44<00:00, 13.26s/it][I 2020-10-07 00:07:23,414] Trial 26 finished with value: 0.17683626865693008 and parameters: {'num_leaves': 5}. Best is trial 24 with value: 0.16254197131599904.
# num_leaves, val_score: 0.162542: 100%|##########| 20/20 [03:44<00:00, 11.21s/it]
# bagging, val_score: 0.162542:   0%|          | 0/10 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031520 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.104085	valid_1's multi_logloss: 0.16353
# Early stopping, best iteration is:
# [112]	training's multi_logloss: 0.0986811	valid_1's multi_logloss: 0.163254
# bagging, val_score: 0.162542:  10%|#         | 1/10 [00:12<01:48, 12.03s/it][I 2020-10-07 00:07:35,465] Trial 27 finished with value: 0.16325390541997664 and parameters: {'bagging_fraction': 0.7109350785290839, 'bagging_freq': 2}. Best is trial 27 with value: 0.16325390541997664.
# bagging, val_score: 0.162542:  10%|#         | 1/10 [00:12<01:48, 12.03s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023411 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.108671	valid_1's multi_logloss: 0.166442
# Early stopping, best iteration is:
# [97]	training's multi_logloss: 0.110069	valid_1's multi_logloss: 0.166283
# bagging, val_score: 0.162542:  20%|##        | 2/10 [00:21<01:31, 11.38s/it][I 2020-10-07 00:07:45,316] Trial 28 finished with value: 0.16628298977295328 and parameters: {'bagging_fraction': 0.40405204991895377, 'bagging_freq': 7}. Best is trial 27 with value: 0.16325390541997664.
# bagging, val_score: 0.162542:  20%|##        | 2/10 [00:21<01:31, 11.38s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002768 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.103732	valid_1's multi_logloss: 0.16301
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.100081	valid_1's multi_logloss: 0.162962
# bagging, val_score: 0.162542:  30%|###       | 3/10 [00:35<01:23, 11.96s/it][I 2020-10-07 00:07:58,628] Trial 29 finished with value: 0.16296248111733166 and parameters: {'bagging_fraction': 0.9974515754767675, 'bagging_freq': 6}. Best is trial 29 with value: 0.16296248111733166.
# bagging, val_score: 0.162542:  30%|###       | 3/10 [00:35<01:23, 11.96s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002868 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.10697	valid_1's multi_logloss: 0.166156
# Early stopping, best iteration is:
# [102]	training's multi_logloss: 0.10603	valid_1's multi_logloss: 0.166078
# bagging, val_score: 0.162542:  40%|####      | 4/10 [00:46<01:10, 11.73s/it][I 2020-10-07 00:08:09,831] Trial 30 finished with value: 0.16607790073979892 and parameters: {'bagging_fraction': 0.4015161390297083, 'bagging_freq': 1}. Best is trial 29 with value: 0.16296248111733166.
# bagging, val_score: 0.162542:  40%|####      | 4/10 [00:46<01:10, 11.73s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.103634	valid_1's multi_logloss: 0.163063
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.0998926	valid_1's multi_logloss: 0.162873
# bagging, val_score: 0.162542:  50%|#####     | 5/10 [01:02<01:05, 13.08s/it][I 2020-10-07 00:08:26,055] Trial 31 finished with value: 0.16287346116832266 and parameters: {'bagging_fraction': 0.9894310468058118, 'bagging_freq': 4}. Best is trial 31 with value: 0.16287346116832266.
# bagging, val_score: 0.162542:  50%|#####     | 5/10 [01:02<01:05, 13.08s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025071 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.104404	valid_1's multi_logloss: 0.164081
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.100418	valid_1's multi_logloss: 0.163897
# bagging, val_score: 0.162542:  60%|######    | 6/10 [01:19<00:56, 14.17s/it][I 2020-10-07 00:08:42,754] Trial 32 finished with value: 0.16389717165878365 and parameters: {'bagging_fraction': 0.6819520228643522, 'bagging_freq': 4}. Best is trial 31 with value: 0.16287346116832266.
# bagging, val_score: 0.162542:  60%|######    | 6/10 [01:19<00:56, 14.17s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.020332 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.104122	valid_1's multi_logloss: 0.163818
# Early stopping, best iteration is:
# [112]	training's multi_logloss: 0.0990071	valid_1's multi_logloss: 0.163578
# bagging, val_score: 0.162542:  70%|#######   | 7/10 [01:31<00:40, 13.42s/it][I 2020-10-07 00:08:54,433] Trial 33 finished with value: 0.16357776625618403 and parameters: {'bagging_fraction': 0.7627699595959357, 'bagging_freq': 6}. Best is trial 31 with value: 0.16287346116832266.
# bagging, val_score: 0.162542:  70%|#######   | 7/10 [01:31<00:40, 13.42s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002843 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.105391	valid_1's multi_logloss: 0.164739
# Early stopping, best iteration is:
# [112]	training's multi_logloss: 0.100083	valid_1's multi_logloss: 0.164344
# bagging, val_score: 0.162542:  80%|########  | 8/10 [01:43<00:26, 13.10s/it][I 2020-10-07 00:09:06,772] Trial 34 finished with value: 0.16434442206197522 and parameters: {'bagging_fraction': 0.5480177076431789, 'bagging_freq': 2}. Best is trial 31 with value: 0.16287346116832266.
# bagging, val_score: 0.162542:  80%|########  | 8/10 [01:43<00:26, 13.10s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025986 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.103693	valid_1's multi_logloss: 0.163361
# Early stopping, best iteration is:
# [105]	training's multi_logloss: 0.101458	valid_1's multi_logloss: 0.163244
# bagging, val_score: 0.162542:  90%|######### | 9/10 [01:54<00:12, 12.58s/it][I 2020-10-07 00:09:18,157] Trial 35 finished with value: 0.1632435611843759 and parameters: {'bagging_fraction': 0.8746846811937128, 'bagging_freq': 3}. Best is trial 31 with value: 0.16287346116832266.
# bagging, val_score: 0.162542:  90%|######### | 9/10 [01:54<00:12, 12.58s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023695 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.106005	valid_1's multi_logloss: 0.164764
# Early stopping, best iteration is:
# [107]	training's multi_logloss: 0.102808	valid_1's multi_logloss: 0.164567
# bagging, val_score: 0.162542: 100%|##########| 10/10 [02:04<00:00, 11.83s/it][I 2020-10-07 00:09:28,247] Trial 36 finished with value: 0.16456725210352705 and parameters: {'bagging_fraction': 0.5432351085115835, 'bagging_freq': 5}. Best is trial 31 with value: 0.16287346116832266.
# bagging, val_score: 0.162542: 100%|##########| 10/10 [02:04<00:00, 12.48s/it]
# feature_fraction_stage2, val_score: 0.162542:   0%|          | 0/6 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.103673	valid_1's multi_logloss: 0.162714
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.0998601	valid_1's multi_logloss: 0.162542
# feature_fraction_stage2, val_score: 0.162542:  17%|#6        | 1/6 [00:10<00:51, 10.30s/it][I 2020-10-07 00:09:38,561] Trial 37 finished with value: 0.16254197131599904 and parameters: {'feature_fraction': 0.5479999999999999}. Best is trial 37 with value: 0.16254197131599904.
# feature_fraction_stage2, val_score: 0.162542:  17%|#6        | 1/6 [00:10<00:51, 10.30s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031657 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.10771	valid_1's multi_logloss: 0.164446
# Early stopping, best iteration is:
# [144]	training's multi_logloss: 0.0907725	valid_1's multi_logloss: 0.163589
# feature_fraction_stage2, val_score: 0.162542:  33%|###3      | 2/6 [00:22<00:43, 10.93s/it][I 2020-10-07 00:09:50,960] Trial 38 finished with value: 0.16358863130521487 and parameters: {'feature_fraction': 0.42}. Best is trial 37 with value: 0.16254197131599904.
# feature_fraction_stage2, val_score: 0.162542:  33%|###3      | 2/6 [00:22<00:43, 10.93s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032575 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.103673	valid_1's multi_logloss: 0.162714
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 0.0998601	valid_1's multi_logloss: 0.162542
# feature_fraction_stage2, val_score: 0.162542:  50%|#####     | 3/6 [00:32<00:32, 10.70s/it][I 2020-10-07 00:10:01,136] Trial 39 finished with value: 0.16254197131599904 and parameters: {'feature_fraction': 0.516}. Best is trial 37 with value: 0.16254197131599904.
# feature_fraction_stage2, val_score: 0.162542:  50%|#####     | 3/6 [00:32<00:32, 10.70s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002646 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.104905	valid_1's multi_logloss: 0.163445
# Early stopping, best iteration is:
# [112]	training's multi_logloss: 0.0998743	valid_1's multi_logloss: 0.16309
# feature_fraction_stage2, val_score: 0.162542:  67%|######6   | 4/6 [00:44<00:22, 11.07s/it][I 2020-10-07 00:10:13,067] Trial 40 finished with value: 0.16308951256475301 and parameters: {'feature_fraction': 0.484}. Best is trial 37 with value: 0.16254197131599904.
# feature_fraction_stage2, val_score: 0.162542:  67%|######6   | 4/6 [00:44<00:22, 11.07s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.102473	valid_1's multi_logloss: 0.162914
# Early stopping, best iteration is:
# [123]	training's multi_logloss: 0.093636	valid_1's multi_logloss: 0.162805
# feature_fraction_stage2, val_score: 0.162542:  83%|########3 | 5/6 [00:57<00:11, 11.61s/it][I 2020-10-07 00:10:25,916] Trial 41 finished with value: 0.16280534686282258 and parameters: {'feature_fraction': 0.58}. Best is trial 37 with value: 0.16254197131599904.
# feature_fraction_stage2, val_score: 0.162542:  83%|########3 | 5/6 [00:57<00:11, 11.61s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026193 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# Training until validation scores don't improve for 10 rounds
# [100]	training's multi_logloss: 0.104905	valid_1's multi_logloss: 0.163445
# Early stopping, best iteration is:
# [112]	training's multi_logloss: 0.0998743	valid_1's multi_logloss: 0.16309
# feature_fraction_stage2, val_score: 0.162542: 100%|##########| 6/6 [01:07<00:00, 11.12s/it][I 2020-10-07 00:10:35,903] Trial 42 finished with value: 0.16308951256475301 and parameters: {'feature_fraction': 0.45199999999999996}. Best is trial 37 with value: 0.16254197131599904.
# feature_fraction_stage2, val_score: 0.162542: 100%|##########| 6/6 [01:07<00:00, 11.28s/it]
# regularization_factors, val_score: 0.162542:   0%|          | 0/20 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030993 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# ...
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's multi_logloss: 0.116172	valid_1's multi_logloss: 0.163127
# Early stopping, best iteration is:
# [143]	training's multi_logloss: 0.102986	valid_1's multi_logloss: 0.162475
# min_data_in_leaf, val_score: 0.161850:  60%|######    | 3/5 [01:52<01:09, 34.62s/it][I 2020-10-07 00:17:29,029] Trial 65 finished with value: 0.16247485926283564 and parameters: {'min_child_samples': 5}. Best is trial 64 with value: 0.16190941703057038.
# min_data_in_leaf, val_score: 0.161850:  60%|######    | 3/5 [01:52<01:09, 34.62s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.207738 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's multi_logloss: 0.118238	valid_1's multi_logloss: 0.163438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [149]	training's multi_logloss: 0.10299	valid_1's multi_logloss: 0.162667
# min_data_in_leaf, val_score: 0.161850:  80%|########  | 4/5 [04:09<01:05, 65.32s/it][I 2020-10-07 00:19:45,999] Trial 66 finished with value: 0.1626665559425435 and parameters: {'min_child_samples': 100}. Best is trial 64 with value: 0.16190941703057038.
# min_data_in_leaf, val_score: 0.161850:  80%|########  | 4/5 [04:09<01:05, 65.32s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.288554 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4586
# [LightGBM] [Info] Number of data points in the train set: 256000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.980965
# [LightGBM] [Info] Start training from score -2.012659
# [LightGBM] [Info] Start training from score -0.710460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's multi_logloss: 0.116426	valid_1's multi_logloss: 0.163074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [142]	training's multi_logloss: 0.103435	valid_1's multi_logloss: 0.162483
# min_data_in_leaf, val_score: 0.161850: 100%|##########| 5/5 [25:29<00:00, 429.61s/it][I 2020-10-07 00:41:05,602] Trial 67 finished with value: 0.16248279567794874 and parameters: {'min_child_samples': 10}. Best is trial 64 with value: 0.16190941703057038.
# min_data_in_leaf, val_score: 0.161850: 100%|##########| 5/5 [25:29<00:00, 305.83s/it]
# Best params: {'objective': 'multiclass', 'metric': 'multi_logloss', 'num_class': 3, 'lambda_l1': 1.0403662686705014e-08, 'lambda_l2': 8.02971174443734, 'random_state': 42, 'n_jobs': -1, 'feature_pre_filter': False, 'bagging_freq': 1, 'num_leaves': 228, 'feature_fraction': 0.5, 'bagging_fraction': 1.0, 'min_child_samples': 20, 'num_iterations': 1000, 'early_stopping_round': 10}
#   Accuracy = 0.9318125
#   Params:
#     objective: multiclass
#     metric: multi_logloss
#     num_class: 3
#     lambda_l1: 1.0403662686705014e-08
#     lambda_l2: 8.02971174443734
#     random_state: 42
#     n_jobs: -1
#     feature_pre_filter: False
#     bagging_freq: 1
#     num_leaves: 228
#     feature_fraction: 0.5
#     bagging_fraction: 1.0
#     min_child_samples: 20
#     num_iterations: 1000
#     early_stopping_round: 10

# %% [markdown]
# ## Stratified K-Fold Cross Validation

# %%
cv = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)

# %% [markdown]
# ## LightGBM 모델 학습

# %%
p_val = np.zeros((trn.shape[0], n_class))
p_tst = np.zeros((tst.shape[0], n_class))
for i, (i_trn, i_val) in enumerate(cv.split(trn, y), 1):
    print(f'training model for CV #{i}')
    clf = LGBMClassifier(**params)
    clf.fit(trn[i_trn], y[i_trn],
            eval_set=[(trn[i_val], y[i_val])],
            eval_metric='multiclass',
            early_stopping_rounds=10)
    
    p_val[i_val, :] = clf.predict_proba(trn[i_val])
    p_tst += clf.predict_proba(tst) / n_fold
# Out:
# training model for CV #1
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=1.0403662686705014e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0403662686705014e-08
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] lambda_l2 is set=8.02971174443734, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.02971174443734
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [1]	valid_0's multi_logloss: 0.857253
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.755674
# [3]	valid_0's multi_logloss: 0.672117
# [4]	valid_0's multi_logloss: 0.600251
# [5]	valid_0's multi_logloss: 0.543144
# [6]	valid_0's multi_logloss: 0.502631
# [7]	valid_0's multi_logloss: 0.467317
# [8]	valid_0's multi_logloss: 0.441069
# [9]	valid_0's multi_logloss: 0.412406
# [10]	valid_0's multi_logloss: 0.384268
# [11]	valid_0's multi_logloss: 0.363314
# [12]	valid_0's multi_logloss: 0.342204
# [13]	valid_0's multi_logloss: 0.324147
# [14]	valid_0's multi_logloss: 0.309903
# [15]	valid_0's multi_logloss: 0.297581
# [16]	valid_0's multi_logloss: 0.283992
# [17]	valid_0's multi_logloss: 0.2726
# [18]	valid_0's multi_logloss: 0.261817
# [19]	valid_0's multi_logloss: 0.252934
# [20]	valid_0's multi_logloss: 0.245633
# [21]	valid_0's multi_logloss: 0.238559
# [22]	valid_0's multi_logloss: 0.233224
# [23]	valid_0's multi_logloss: 0.226628
# [24]	valid_0's multi_logloss: 0.222049
# [25]	valid_0's multi_logloss: 0.217532
# [26]	valid_0's multi_logloss: 0.214167
# [27]	valid_0's multi_logloss: 0.209918
# [28]	valid_0's multi_logloss: 0.207412
# [29]	valid_0's multi_logloss: 0.20332
# [30]	valid_0's multi_logloss: 0.200885
# [31]	valid_0's multi_logloss: 0.198388
# [32]	valid_0's multi_logloss: 0.195791
# [33]	valid_0's multi_logloss: 0.193359
# [34]	valid_0's multi_logloss: 0.190956
# [35]	valid_0's multi_logloss: 0.188357
# [36]	valid_0's multi_logloss: 0.186964
# [37]	valid_0's multi_logloss: 0.185881
# [38]	valid_0's multi_logloss: 0.184431
# [39]	valid_0's multi_logloss: 0.183248
# [40]	valid_0's multi_logloss: 0.181932
# [41]	valid_0's multi_logloss: 0.180839
# [42]	valid_0's multi_logloss: 0.179564
# [43]	valid_0's multi_logloss: 0.178289
# [44]	valid_0's multi_logloss: 0.176881
# [45]	valid_0's multi_logloss: 0.176127
# [46]	valid_0's multi_logloss: 0.175505
# [47]	valid_0's multi_logloss: 0.174917
# [48]	valid_0's multi_logloss: 0.174154
# [49]	valid_0's multi_logloss: 0.173214
# [50]	valid_0's multi_logloss: 0.172303
# [51]	valid_0's multi_logloss: 0.171364
# [52]	valid_0's multi_logloss: 0.17073
# [53]	valid_0's multi_logloss: 0.169913
# [54]	valid_0's multi_logloss: 0.169764
# [55]	valid_0's multi_logloss: 0.16937
# [56]	valid_0's multi_logloss: 0.168975
# [57]	valid_0's multi_logloss: 0.168746
# [58]	valid_0's multi_logloss: 0.168432
# [59]	valid_0's multi_logloss: 0.16804
# [60]	valid_0's multi_logloss: 0.167686
# [61]	valid_0's multi_logloss: 0.167123
# [62]	valid_0's multi_logloss: 0.166967
# [63]	valid_0's multi_logloss: 0.166579
# [64]	valid_0's multi_logloss: 0.166094
# [65]	valid_0's multi_logloss: 0.165789
# [66]	valid_0's multi_logloss: 0.165451
# [67]	valid_0's multi_logloss: 0.165128
# [68]	valid_0's multi_logloss: 0.16482
# [69]	valid_0's multi_logloss: 0.164505
# [70]	valid_0's multi_logloss: 0.164247
# [71]	valid_0's multi_logloss: 0.16406
# [72]	valid_0's multi_logloss: 0.163833
# [73]	valid_0's multi_logloss: 0.163702
# [74]	valid_0's multi_logloss: 0.163437
# [75]	valid_0's multi_logloss: 0.163325
# [76]	valid_0's multi_logloss: 0.163033
# [77]	valid_0's multi_logloss: 0.162888
# [78]	valid_0's multi_logloss: 0.16277
# [79]	valid_0's multi_logloss: 0.162599
# [80]	valid_0's multi_logloss: 0.162542
# [81]	valid_0's multi_logloss: 0.162366
# [82]	valid_0's multi_logloss: 0.16212
# [83]	valid_0's multi_logloss: 0.161958
# [84]	valid_0's multi_logloss: 0.161862
# [85]	valid_0's multi_logloss: 0.16168
# [86]	valid_0's multi_logloss: 0.161619
# [87]	valid_0's multi_logloss: 0.161516
# [88]	valid_0's multi_logloss: 0.161385
# [89]	valid_0's multi_logloss: 0.161335
# [90]	valid_0's multi_logloss: 0.161293
# [91]	valid_0's multi_logloss: 0.161221
# [92]	valid_0's multi_logloss: 0.161104
# [93]	valid_0's multi_logloss: 0.161049
# [94]	valid_0's multi_logloss: 0.160981
# [95]	valid_0's multi_logloss: 0.160919
# [96]	valid_0's multi_logloss: 0.160872
# [97]	valid_0's multi_logloss: 0.16079
# [98]	valid_0's multi_logloss: 0.160792
# [99]	valid_0's multi_logloss: 0.160737
# [100]	valid_0's multi_logloss: 0.160683
# [101]	valid_0's multi_logloss: 0.16066
# [102]	valid_0's multi_logloss: 0.160618
# [103]	valid_0's multi_logloss: 0.160537
# [104]	valid_0's multi_logloss: 0.160499
# [105]	valid_0's multi_logloss: 0.16048
# [106]	valid_0's multi_logloss: 0.160435
# [107]	valid_0's multi_logloss: 0.160397
# [108]	valid_0's multi_logloss: 0.160338
# [109]	valid_0's multi_logloss: 0.160322
# [110]	valid_0's multi_logloss: 0.160346
# [111]	valid_0's multi_logloss: 0.160306
# [112]	valid_0's multi_logloss: 0.160209
# [113]	valid_0's multi_logloss: 0.160235
# [114]	valid_0's multi_logloss: 0.160213
# [115]	valid_0's multi_logloss: 0.16024
# [116]	valid_0's multi_logloss: 0.160217
# [117]	valid_0's multi_logloss: 0.160155
# [118]	valid_0's multi_logloss: 0.160157
# [119]	valid_0's multi_logloss: 0.160105
# [120]	valid_0's multi_logloss: 0.160112
# [121]	valid_0's multi_logloss: 0.1601
# [122]	valid_0's multi_logloss: 0.160099
# [123]	valid_0's multi_logloss: 0.160079
# [124]	valid_0's multi_logloss: 0.159995
# [125]	valid_0's multi_logloss: 0.159981
# [126]	valid_0's multi_logloss: 0.160005
# [127]	valid_0's multi_logloss: 0.159978
# [128]	valid_0's multi_logloss: 0.159966
# [129]	valid_0's multi_logloss: 0.15993
# [130]	valid_0's multi_logloss: 0.159932
# [131]	valid_0's multi_logloss: 0.159915
# [132]	valid_0's multi_logloss: 0.1599
# [133]	valid_0's multi_logloss: 0.159886
# [134]	valid_0's multi_logloss: 0.15988
# [135]	valid_0's multi_logloss: 0.159855
# [136]	valid_0's multi_logloss: 0.159874
# [137]	valid_0's multi_logloss: 0.159884
# [138]	valid_0's multi_logloss: 0.159895
# [139]	valid_0's multi_logloss: 0.159875
# [140]	valid_0's multi_logloss: 0.159863
# [141]	valid_0's multi_logloss: 0.159837
# [142]	valid_0's multi_logloss: 0.159831
# [143]	valid_0's multi_logloss: 0.159831
# [144]	valid_0's multi_logloss: 0.159814
# [145]	valid_0's multi_logloss: 0.159802
# [146]	valid_0's multi_logloss: 0.159773
# [147]	valid_0's multi_logloss: 0.159789
# [148]	valid_0's multi_logloss: 0.15978
# [149]	valid_0's multi_logloss: 0.159782
# [150]	valid_0's multi_logloss: 0.15976
# [151]	valid_0's multi_logloss: 0.159749
# [152]	valid_0's multi_logloss: 0.159766
# [153]	valid_0's multi_logloss: 0.159789
# [154]	valid_0's multi_logloss: 0.159779
# [155]	valid_0's multi_logloss: 0.159784
# [156]	valid_0's multi_logloss: 0.15979
# [157]	valid_0's multi_logloss: 0.159805
# [158]	valid_0's multi_logloss: 0.159814
# [159]	valid_0's multi_logloss: 0.159801
# [160]	valid_0's multi_logloss: 0.159816
# [161]	valid_0's multi_logloss: 0.15981
# Early stopping, best iteration is:
# [151]	valid_0's multi_logloss: 0.159749
# training model for CV #2
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=1.0403662686705014e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0403662686705014e-08
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] lambda_l2 is set=8.02971174443734, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.02971174443734
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [1]	valid_0's multi_logloss: 0.857813
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.756112
# [3]	valid_0's multi_logloss: 0.672357
# [4]	valid_0's multi_logloss: 0.600668
# [5]	valid_0's multi_logloss: 0.5438
# [6]	valid_0's multi_logloss: 0.503249
# [7]	valid_0's multi_logloss: 0.468034
# [8]	valid_0's multi_logloss: 0.442066
# [9]	valid_0's multi_logloss: 0.413411
# [10]	valid_0's multi_logloss: 0.385273
# [11]	valid_0's multi_logloss: 0.364294
# [12]	valid_0's multi_logloss: 0.343187
# [13]	valid_0's multi_logloss: 0.324985
# [14]	valid_0's multi_logloss: 0.310746
# [15]	valid_0's multi_logloss: 0.298486
# [16]	valid_0's multi_logloss: 0.284927
# [17]	valid_0's multi_logloss: 0.27344
# [18]	valid_0's multi_logloss: 0.262679
# [19]	valid_0's multi_logloss: 0.253833
# [20]	valid_0's multi_logloss: 0.246512
# [21]	valid_0's multi_logloss: 0.239348
# [22]	valid_0's multi_logloss: 0.233888
# [23]	valid_0's multi_logloss: 0.227226
# [24]	valid_0's multi_logloss: 0.2226
# [25]	valid_0's multi_logloss: 0.217998
# [26]	valid_0's multi_logloss: 0.214668
# [27]	valid_0's multi_logloss: 0.21049
# [28]	valid_0's multi_logloss: 0.207912
# [29]	valid_0's multi_logloss: 0.203907
# [30]	valid_0's multi_logloss: 0.201367
# [31]	valid_0's multi_logloss: 0.198909
# [32]	valid_0's multi_logloss: 0.196316
# [33]	valid_0's multi_logloss: 0.193875
# [34]	valid_0's multi_logloss: 0.191458
# [35]	valid_0's multi_logloss: 0.188868
# [36]	valid_0's multi_logloss: 0.18746
# [37]	valid_0's multi_logloss: 0.186354
# [38]	valid_0's multi_logloss: 0.184841
# [39]	valid_0's multi_logloss: 0.183638
# [40]	valid_0's multi_logloss: 0.182353
# [41]	valid_0's multi_logloss: 0.181257
# [42]	valid_0's multi_logloss: 0.179927
# [43]	valid_0's multi_logloss: 0.178664
# [44]	valid_0's multi_logloss: 0.177267
# [45]	valid_0's multi_logloss: 0.176472
# [46]	valid_0's multi_logloss: 0.175792
# [47]	valid_0's multi_logloss: 0.175204
# [48]	valid_0's multi_logloss: 0.174515
# [49]	valid_0's multi_logloss: 0.173666
# [50]	valid_0's multi_logloss: 0.172806
# [51]	valid_0's multi_logloss: 0.171902
# [52]	valid_0's multi_logloss: 0.171258
# [53]	valid_0's multi_logloss: 0.170455
# [54]	valid_0's multi_logloss: 0.170236
# [55]	valid_0's multi_logloss: 0.16988
# [56]	valid_0's multi_logloss: 0.169451
# [57]	valid_0's multi_logloss: 0.169165
# [58]	valid_0's multi_logloss: 0.168858
# [59]	valid_0's multi_logloss: 0.168484
# [60]	valid_0's multi_logloss: 0.168098
# [61]	valid_0's multi_logloss: 0.167512
# [62]	valid_0's multi_logloss: 0.167297
# [63]	valid_0's multi_logloss: 0.166909
# [64]	valid_0's multi_logloss: 0.166491
# [65]	valid_0's multi_logloss: 0.166161
# [66]	valid_0's multi_logloss: 0.165799
# [67]	valid_0's multi_logloss: 0.165471
# [68]	valid_0's multi_logloss: 0.165167
# [69]	valid_0's multi_logloss: 0.164903
# [70]	valid_0's multi_logloss: 0.164658
# [71]	valid_0's multi_logloss: 0.164418
# [72]	valid_0's multi_logloss: 0.164237
# [73]	valid_0's multi_logloss: 0.164113
# [74]	valid_0's multi_logloss: 0.163906
# [75]	valid_0's multi_logloss: 0.163747
# [76]	valid_0's multi_logloss: 0.163474
# [77]	valid_0's multi_logloss: 0.163274
# [78]	valid_0's multi_logloss: 0.16316
# [79]	valid_0's multi_logloss: 0.162984
# [80]	valid_0's multi_logloss: 0.162873
# [81]	valid_0's multi_logloss: 0.162682
# [82]	valid_0's multi_logloss: 0.162477
# [83]	valid_0's multi_logloss: 0.162393
# [84]	valid_0's multi_logloss: 0.162284
# [85]	valid_0's multi_logloss: 0.162127
# [86]	valid_0's multi_logloss: 0.162049
# [87]	valid_0's multi_logloss: 0.161955
# [88]	valid_0's multi_logloss: 0.161787
# [89]	valid_0's multi_logloss: 0.161736
# [90]	valid_0's multi_logloss: 0.161683
# [91]	valid_0's multi_logloss: 0.161616
# [92]	valid_0's multi_logloss: 0.161514
# [93]	valid_0's multi_logloss: 0.161468
# [94]	valid_0's multi_logloss: 0.161418
# [95]	valid_0's multi_logloss: 0.16136
# [96]	valid_0's multi_logloss: 0.161275
# [97]	valid_0's multi_logloss: 0.161205
# [98]	valid_0's multi_logloss: 0.161184
# [99]	valid_0's multi_logloss: 0.161098
# [100]	valid_0's multi_logloss: 0.161043
# [101]	valid_0's multi_logloss: 0.161037
# [102]	valid_0's multi_logloss: 0.16098
# [103]	valid_0's multi_logloss: 0.160908
# [104]	valid_0's multi_logloss: 0.160849
# [105]	valid_0's multi_logloss: 0.160841
# [106]	valid_0's multi_logloss: 0.160835
# [107]	valid_0's multi_logloss: 0.160826
# [108]	valid_0's multi_logloss: 0.16078
# [109]	valid_0's multi_logloss: 0.160782
# [110]	valid_0's multi_logloss: 0.160796
# [111]	valid_0's multi_logloss: 0.160788
# [112]	valid_0's multi_logloss: 0.160729
# [113]	valid_0's multi_logloss: 0.160742
# [114]	valid_0's multi_logloss: 0.160736
# [115]	valid_0's multi_logloss: 0.160712
# [116]	valid_0's multi_logloss: 0.160706
# [117]	valid_0's multi_logloss: 0.160646
# [118]	valid_0's multi_logloss: 0.160641
# [119]	valid_0's multi_logloss: 0.1606
# [120]	valid_0's multi_logloss: 0.160559
# [121]	valid_0's multi_logloss: 0.160545
# [122]	valid_0's multi_logloss: 0.160523
# [123]	valid_0's multi_logloss: 0.160501
# [124]	valid_0's multi_logloss: 0.160462
# [125]	valid_0's multi_logloss: 0.160459
# [126]	valid_0's multi_logloss: 0.160432
# [127]	valid_0's multi_logloss: 0.160448
# [128]	valid_0's multi_logloss: 0.160466
# [129]	valid_0's multi_logloss: 0.160442
# [130]	valid_0's multi_logloss: 0.160408
# [131]	valid_0's multi_logloss: 0.160425
# [132]	valid_0's multi_logloss: 0.160425
# [133]	valid_0's multi_logloss: 0.16042
# [134]	valid_0's multi_logloss: 0.160426
# [135]	valid_0's multi_logloss: 0.160387
# [136]	valid_0's multi_logloss: 0.160409
# [137]	valid_0's multi_logloss: 0.16038
# [138]	valid_0's multi_logloss: 0.160364
# [139]	valid_0's multi_logloss: 0.160357
# [140]	valid_0's multi_logloss: 0.16032
# [141]	valid_0's multi_logloss: 0.160308
# [142]	valid_0's multi_logloss: 0.160286
# [143]	valid_0's multi_logloss: 0.160295
# [144]	valid_0's multi_logloss: 0.160303
# [145]	valid_0's multi_logloss: 0.160313
# [146]	valid_0's multi_logloss: 0.160301
# [147]	valid_0's multi_logloss: 0.160313
# [148]	valid_0's multi_logloss: 0.160321
# [149]	valid_0's multi_logloss: 0.160295
# [150]	valid_0's multi_logloss: 0.160279
# [151]	valid_0's multi_logloss: 0.160298
# [152]	valid_0's multi_logloss: 0.160287
# [153]	valid_0's multi_logloss: 0.160259
# [154]	valid_0's multi_logloss: 0.160251
# [155]	valid_0's multi_logloss: 0.160224
# [156]	valid_0's multi_logloss: 0.160219
# [157]	valid_0's multi_logloss: 0.160219
# [158]	valid_0's multi_logloss: 0.160235
# [159]	valid_0's multi_logloss: 0.160253
# [160]	valid_0's multi_logloss: 0.160247
# [161]	valid_0's multi_logloss: 0.160258
# [162]	valid_0's multi_logloss: 0.160254
# [163]	valid_0's multi_logloss: 0.160247
# [164]	valid_0's multi_logloss: 0.160228
# [165]	valid_0's multi_logloss: 0.160205
# [166]	valid_0's multi_logloss: 0.160231
# [167]	valid_0's multi_logloss: 0.16023
# [168]	valid_0's multi_logloss: 0.160205
# [169]	valid_0's multi_logloss: 0.160202
# [170]	valid_0's multi_logloss: 0.160211
# [171]	valid_0's multi_logloss: 0.160223
# [172]	valid_0's multi_logloss: 0.160207
# [173]	valid_0's multi_logloss: 0.160221
# [174]	valid_0's multi_logloss: 0.160222
# [175]	valid_0's multi_logloss: 0.16022
# [176]	valid_0's multi_logloss: 0.160225
# [177]	valid_0's multi_logloss: 0.160235
# [178]	valid_0's multi_logloss: 0.160255
# [179]	valid_0's multi_logloss: 0.160264
# Early stopping, best iteration is:
# [169]	valid_0's multi_logloss: 0.160202
# training model for CV #3
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=1.0403662686705014e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0403662686705014e-08
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] lambda_l2 is set=8.02971174443734, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.02971174443734
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [1]	valid_0's multi_logloss: 0.857214
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.755593
# [3]	valid_0's multi_logloss: 0.672432
# [4]	valid_0's multi_logloss: 0.600697
# [5]	valid_0's multi_logloss: 0.544034
# [6]	valid_0's multi_logloss: 0.503533
# [7]	valid_0's multi_logloss: 0.468481
# [8]	valid_0's multi_logloss: 0.442343
# [9]	valid_0's multi_logloss: 0.413896
# [10]	valid_0's multi_logloss: 0.385883
# [11]	valid_0's multi_logloss: 0.36509
# [12]	valid_0's multi_logloss: 0.344046
# [13]	valid_0's multi_logloss: 0.32609
# [14]	valid_0's multi_logloss: 0.311792
# [15]	valid_0's multi_logloss: 0.299477
# [16]	valid_0's multi_logloss: 0.285996
# [17]	valid_0's multi_logloss: 0.274575
# [18]	valid_0's multi_logloss: 0.263742
# [19]	valid_0's multi_logloss: 0.254787
# [20]	valid_0's multi_logloss: 0.247528
# [21]	valid_0's multi_logloss: 0.240415
# [22]	valid_0's multi_logloss: 0.235079
# [23]	valid_0's multi_logloss: 0.228522
# [24]	valid_0's multi_logloss: 0.223938
# [25]	valid_0's multi_logloss: 0.219331
# [26]	valid_0's multi_logloss: 0.215943
# [27]	valid_0's multi_logloss: 0.211732
# [28]	valid_0's multi_logloss: 0.209165
# [29]	valid_0's multi_logloss: 0.205033
# [30]	valid_0's multi_logloss: 0.202649
# [31]	valid_0's multi_logloss: 0.200165
# [32]	valid_0's multi_logloss: 0.197587
# [33]	valid_0's multi_logloss: 0.195157
# [34]	valid_0's multi_logloss: 0.192758
# [35]	valid_0's multi_logloss: 0.190027
# [36]	valid_0's multi_logloss: 0.188669
# [37]	valid_0's multi_logloss: 0.187612
# [38]	valid_0's multi_logloss: 0.186111
# [39]	valid_0's multi_logloss: 0.184898
# [40]	valid_0's multi_logloss: 0.183607
# [41]	valid_0's multi_logloss: 0.18245
# [42]	valid_0's multi_logloss: 0.181203
# [43]	valid_0's multi_logloss: 0.179954
# [44]	valid_0's multi_logloss: 0.178505
# [45]	valid_0's multi_logloss: 0.177694
# [46]	valid_0's multi_logloss: 0.177028
# [47]	valid_0's multi_logloss: 0.176418
# [48]	valid_0's multi_logloss: 0.175758
# [49]	valid_0's multi_logloss: 0.174817
# [50]	valid_0's multi_logloss: 0.173882
# [51]	valid_0's multi_logloss: 0.172913
# [52]	valid_0's multi_logloss: 0.172251
# [53]	valid_0's multi_logloss: 0.17137
# [54]	valid_0's multi_logloss: 0.171195
# [55]	valid_0's multi_logloss: 0.170825
# [56]	valid_0's multi_logloss: 0.170415
# [57]	valid_0's multi_logloss: 0.170184
# [58]	valid_0's multi_logloss: 0.169877
# [59]	valid_0's multi_logloss: 0.169475
# [60]	valid_0's multi_logloss: 0.169103
# [61]	valid_0's multi_logloss: 0.168514
# [62]	valid_0's multi_logloss: 0.168315
# [63]	valid_0's multi_logloss: 0.167888
# [64]	valid_0's multi_logloss: 0.16741
# [65]	valid_0's multi_logloss: 0.167154
# [66]	valid_0's multi_logloss: 0.166783
# [67]	valid_0's multi_logloss: 0.16642
# [68]	valid_0's multi_logloss: 0.166118
# [69]	valid_0's multi_logloss: 0.165841
# [70]	valid_0's multi_logloss: 0.16557
# [71]	valid_0's multi_logloss: 0.165375
# [72]	valid_0's multi_logloss: 0.165159
# [73]	valid_0's multi_logloss: 0.165056
# [74]	valid_0's multi_logloss: 0.164756
# [75]	valid_0's multi_logloss: 0.164592
# [76]	valid_0's multi_logloss: 0.16427
# [77]	valid_0's multi_logloss: 0.164125
# [78]	valid_0's multi_logloss: 0.163991
# [79]	valid_0's multi_logloss: 0.16383
# [80]	valid_0's multi_logloss: 0.163735
# [81]	valid_0's multi_logloss: 0.163577
# [82]	valid_0's multi_logloss: 0.163359
# [83]	valid_0's multi_logloss: 0.163258
# [84]	valid_0's multi_logloss: 0.163157
# [85]	valid_0's multi_logloss: 0.163031
# [86]	valid_0's multi_logloss: 0.162978
# [87]	valid_0's multi_logloss: 0.162862
# [88]	valid_0's multi_logloss: 0.16271
# [89]	valid_0's multi_logloss: 0.162636
# [90]	valid_0's multi_logloss: 0.162574
# [91]	valid_0's multi_logloss: 0.162519
# [92]	valid_0's multi_logloss: 0.16239
# [93]	valid_0's multi_logloss: 0.162326
# [94]	valid_0's multi_logloss: 0.162247
# [95]	valid_0's multi_logloss: 0.162177
# [96]	valid_0's multi_logloss: 0.162136
# [97]	valid_0's multi_logloss: 0.16208
# [98]	valid_0's multi_logloss: 0.162044
# [99]	valid_0's multi_logloss: 0.162003
# [100]	valid_0's multi_logloss: 0.161942
# [101]	valid_0's multi_logloss: 0.161903
# [102]	valid_0's multi_logloss: 0.161836
# [103]	valid_0's multi_logloss: 0.161775
# [104]	valid_0's multi_logloss: 0.161732
# [105]	valid_0's multi_logloss: 0.161719
# [106]	valid_0's multi_logloss: 0.1617
# [107]	valid_0's multi_logloss: 0.161667
# [108]	valid_0's multi_logloss: 0.161625
# [109]	valid_0's multi_logloss: 0.161591
# [110]	valid_0's multi_logloss: 0.161572
# [111]	valid_0's multi_logloss: 0.161539
# [112]	valid_0's multi_logloss: 0.161493
# [113]	valid_0's multi_logloss: 0.161482
# [114]	valid_0's multi_logloss: 0.161504
# [115]	valid_0's multi_logloss: 0.161509
# [116]	valid_0's multi_logloss: 0.161476
# [117]	valid_0's multi_logloss: 0.161424
# [118]	valid_0's multi_logloss: 0.161396
# [119]	valid_0's multi_logloss: 0.161368
# [120]	valid_0's multi_logloss: 0.161385
# [121]	valid_0's multi_logloss: 0.161365
# [122]	valid_0's multi_logloss: 0.161348
# [123]	valid_0's multi_logloss: 0.161319
# [124]	valid_0's multi_logloss: 0.161268
# [125]	valid_0's multi_logloss: 0.161254
# [126]	valid_0's multi_logloss: 0.161259
# [127]	valid_0's multi_logloss: 0.161237
# [128]	valid_0's multi_logloss: 0.161224
# [129]	valid_0's multi_logloss: 0.161196
# [130]	valid_0's multi_logloss: 0.161204
# [131]	valid_0's multi_logloss: 0.161184
# [132]	valid_0's multi_logloss: 0.161165
# [133]	valid_0's multi_logloss: 0.161141
# [134]	valid_0's multi_logloss: 0.16112
# [135]	valid_0's multi_logloss: 0.161087
# [136]	valid_0's multi_logloss: 0.161107
# [137]	valid_0's multi_logloss: 0.161111
# [138]	valid_0's multi_logloss: 0.161113
# [139]	valid_0's multi_logloss: 0.161088
# [140]	valid_0's multi_logloss: 0.161078
# [141]	valid_0's multi_logloss: 0.161056
# [142]	valid_0's multi_logloss: 0.161058
# [143]	valid_0's multi_logloss: 0.161069
# [144]	valid_0's multi_logloss: 0.161074
# [145]	valid_0's multi_logloss: 0.161083
# [146]	valid_0's multi_logloss: 0.161049
# [147]	valid_0's multi_logloss: 0.161052
# [148]	valid_0's multi_logloss: 0.161046
# [149]	valid_0's multi_logloss: 0.16102
# [150]	valid_0's multi_logloss: 0.161012
# [151]	valid_0's multi_logloss: 0.161006
# [152]	valid_0's multi_logloss: 0.161018
# [153]	valid_0's multi_logloss: 0.16099
# [154]	valid_0's multi_logloss: 0.161006
# [155]	valid_0's multi_logloss: 0.161012
# [156]	valid_0's multi_logloss: 0.161055
# [157]	valid_0's multi_logloss: 0.161054
# [158]	valid_0's multi_logloss: 0.16105
# [159]	valid_0's multi_logloss: 0.161046
# [160]	valid_0's multi_logloss: 0.161056
# [161]	valid_0's multi_logloss: 0.161047
# [162]	valid_0's multi_logloss: 0.161044
# [163]	valid_0's multi_logloss: 0.161035
# Early stopping, best iteration is:
# [153]	valid_0's multi_logloss: 0.16099
# training model for CV #4
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=1.0403662686705014e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0403662686705014e-08
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] lambda_l2 is set=8.02971174443734, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.02971174443734
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [1]	valid_0's multi_logloss: 0.857624
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.756135
# [3]	valid_0's multi_logloss: 0.673
# [4]	valid_0's multi_logloss: 0.601213
# [5]	valid_0's multi_logloss: 0.544358
# [6]	valid_0's multi_logloss: 0.504029
# [7]	valid_0's multi_logloss: 0.468899
# [8]	valid_0's multi_logloss: 0.442759
# [9]	valid_0's multi_logloss: 0.414091
# [10]	valid_0's multi_logloss: 0.385939
# [11]	valid_0's multi_logloss: 0.365126
# [12]	valid_0's multi_logloss: 0.344071
# [13]	valid_0's multi_logloss: 0.325915
# [14]	valid_0's multi_logloss: 0.311841
# [15]	valid_0's multi_logloss: 0.299711
# [16]	valid_0's multi_logloss: 0.28609
# [17]	valid_0's multi_logloss: 0.274625
# [18]	valid_0's multi_logloss: 0.263782
# [19]	valid_0's multi_logloss: 0.254982
# [20]	valid_0's multi_logloss: 0.247589
# [21]	valid_0's multi_logloss: 0.240462
# [22]	valid_0's multi_logloss: 0.235084
# [23]	valid_0's multi_logloss: 0.228532
# [24]	valid_0's multi_logloss: 0.223977
# [25]	valid_0's multi_logloss: 0.219366
# [26]	valid_0's multi_logloss: 0.216063
# [27]	valid_0's multi_logloss: 0.211878
# [28]	valid_0's multi_logloss: 0.209349
# [29]	valid_0's multi_logloss: 0.205259
# [30]	valid_0's multi_logloss: 0.20281
# [31]	valid_0's multi_logloss: 0.200411
# [32]	valid_0's multi_logloss: 0.197844
# [33]	valid_0's multi_logloss: 0.195396
# [34]	valid_0's multi_logloss: 0.19293
# [35]	valid_0's multi_logloss: 0.190244
# [36]	valid_0's multi_logloss: 0.188868
# [37]	valid_0's multi_logloss: 0.187771
# [38]	valid_0's multi_logloss: 0.186217
# [39]	valid_0's multi_logloss: 0.185005
# [40]	valid_0's multi_logloss: 0.183706
# [41]	valid_0's multi_logloss: 0.18262
# [42]	valid_0's multi_logloss: 0.181343
# [43]	valid_0's multi_logloss: 0.180128
# [44]	valid_0's multi_logloss: 0.178744
# [45]	valid_0's multi_logloss: 0.177935
# [46]	valid_0's multi_logloss: 0.177249
# [47]	valid_0's multi_logloss: 0.176678
# [48]	valid_0's multi_logloss: 0.175956
# [49]	valid_0's multi_logloss: 0.175099
# [50]	valid_0's multi_logloss: 0.174222
# [51]	valid_0's multi_logloss: 0.173284
# [52]	valid_0's multi_logloss: 0.17266
# [53]	valid_0's multi_logloss: 0.171842
# [54]	valid_0's multi_logloss: 0.171651
# [55]	valid_0's multi_logloss: 0.17128
# [56]	valid_0's multi_logloss: 0.17085
# [57]	valid_0's multi_logloss: 0.170628
# [58]	valid_0's multi_logloss: 0.170333
# [59]	valid_0's multi_logloss: 0.169963
# [60]	valid_0's multi_logloss: 0.169654
# [61]	valid_0's multi_logloss: 0.169009
# [62]	valid_0's multi_logloss: 0.168839
# [63]	valid_0's multi_logloss: 0.168423
# [64]	valid_0's multi_logloss: 0.167942
# [65]	valid_0's multi_logloss: 0.167622
# [66]	valid_0's multi_logloss: 0.16726
# [67]	valid_0's multi_logloss: 0.166852
# [68]	valid_0's multi_logloss: 0.166554
# [69]	valid_0's multi_logloss: 0.166246
# [70]	valid_0's multi_logloss: 0.166006
# [71]	valid_0's multi_logloss: 0.165839
# [72]	valid_0's multi_logloss: 0.165672
# [73]	valid_0's multi_logloss: 0.165576
# [74]	valid_0's multi_logloss: 0.165382
# [75]	valid_0's multi_logloss: 0.165246
# [76]	valid_0's multi_logloss: 0.16498
# [77]	valid_0's multi_logloss: 0.164851
# [78]	valid_0's multi_logloss: 0.164678
# [79]	valid_0's multi_logloss: 0.164483
# [80]	valid_0's multi_logloss: 0.1644
# [81]	valid_0's multi_logloss: 0.164222
# [82]	valid_0's multi_logloss: 0.164029
# [83]	valid_0's multi_logloss: 0.163885
# [84]	valid_0's multi_logloss: 0.16376
# [85]	valid_0's multi_logloss: 0.163608
# [86]	valid_0's multi_logloss: 0.163527
# [87]	valid_0's multi_logloss: 0.163414
# [88]	valid_0's multi_logloss: 0.163272
# [89]	valid_0's multi_logloss: 0.163188
# [90]	valid_0's multi_logloss: 0.163141
# [91]	valid_0's multi_logloss: 0.163063
# [92]	valid_0's multi_logloss: 0.162968
# [93]	valid_0's multi_logloss: 0.162946
# [94]	valid_0's multi_logloss: 0.162827
# [95]	valid_0's multi_logloss: 0.16278
# [96]	valid_0's multi_logloss: 0.162734
# [97]	valid_0's multi_logloss: 0.162634
# [98]	valid_0's multi_logloss: 0.162604
# [99]	valid_0's multi_logloss: 0.162544
# [100]	valid_0's multi_logloss: 0.16251
# [101]	valid_0's multi_logloss: 0.162468
# [102]	valid_0's multi_logloss: 0.162392
# [103]	valid_0's multi_logloss: 0.162294
# [104]	valid_0's multi_logloss: 0.162257
# [105]	valid_0's multi_logloss: 0.162252
# [106]	valid_0's multi_logloss: 0.162246
# [107]	valid_0's multi_logloss: 0.162214
# [108]	valid_0's multi_logloss: 0.16218
# [109]	valid_0's multi_logloss: 0.162153
# [110]	valid_0's multi_logloss: 0.162144
# [111]	valid_0's multi_logloss: 0.162122
# [112]	valid_0's multi_logloss: 0.162088
# [113]	valid_0's multi_logloss: 0.162097
# [114]	valid_0's multi_logloss: 0.162116
# [115]	valid_0's multi_logloss: 0.1621
# [116]	valid_0's multi_logloss: 0.162077
# [117]	valid_0's multi_logloss: 0.162032
# [118]	valid_0's multi_logloss: 0.161993
# [119]	valid_0's multi_logloss: 0.161969
# [120]	valid_0's multi_logloss: 0.161978
# [121]	valid_0's multi_logloss: 0.161958
# [122]	valid_0's multi_logloss: 0.161912
# [123]	valid_0's multi_logloss: 0.161851
# [124]	valid_0's multi_logloss: 0.161768
# [125]	valid_0's multi_logloss: 0.161752
# [126]	valid_0's multi_logloss: 0.161722
# [127]	valid_0's multi_logloss: 0.161715
# [128]	valid_0's multi_logloss: 0.161736
# [129]	valid_0's multi_logloss: 0.161715
# [130]	valid_0's multi_logloss: 0.161698
# [131]	valid_0's multi_logloss: 0.161707
# [132]	valid_0's multi_logloss: 0.16172
# [133]	valid_0's multi_logloss: 0.161698
# [134]	valid_0's multi_logloss: 0.161701
# [135]	valid_0's multi_logloss: 0.161697
# [136]	valid_0's multi_logloss: 0.161695
# [137]	valid_0's multi_logloss: 0.161701
# [138]	valid_0's multi_logloss: 0.161691
# [139]	valid_0's multi_logloss: 0.161696
# [140]	valid_0's multi_logloss: 0.161721
# [141]	valid_0's multi_logloss: 0.161717
# [142]	valid_0's multi_logloss: 0.161702
# [143]	valid_0's multi_logloss: 0.161709
# [144]	valid_0's multi_logloss: 0.161689
# [145]	valid_0's multi_logloss: 0.161679
# [146]	valid_0's multi_logloss: 0.161677
# [147]	valid_0's multi_logloss: 0.161689
# [148]	valid_0's multi_logloss: 0.161682
# [149]	valid_0's multi_logloss: 0.161671
# [150]	valid_0's multi_logloss: 0.161657
# [151]	valid_0's multi_logloss: 0.161645
# [152]	valid_0's multi_logloss: 0.161632
# [153]	valid_0's multi_logloss: 0.161615
# [154]	valid_0's multi_logloss: 0.161587
# [155]	valid_0's multi_logloss: 0.161581
# [156]	valid_0's multi_logloss: 0.16159
# [157]	valid_0's multi_logloss: 0.161577
# [158]	valid_0's multi_logloss: 0.161598
# [159]	valid_0's multi_logloss: 0.161596
# [160]	valid_0's multi_logloss: 0.161609
# [161]	valid_0's multi_logloss: 0.161619
# [162]	valid_0's multi_logloss: 0.161626
# [163]	valid_0's multi_logloss: 0.161618
# [164]	valid_0's multi_logloss: 0.16162
# [165]	valid_0's multi_logloss: 0.161597
# [166]	valid_0's multi_logloss: 0.161611
# [167]	valid_0's multi_logloss: 0.161618
# Early stopping, best iteration is:
# [157]	valid_0's multi_logloss: 0.161577
# training model for CV #5
# [LightGBM] [Warning] feature_fraction is set=0.5, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5
# [LightGBM] [Warning] lambda_l1 is set=1.0403662686705014e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0403662686705014e-08
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] lambda_l2 is set=8.02971174443734, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.02971174443734
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [1]	valid_0's multi_logloss: 0.857709
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.756183
# [3]	valid_0's multi_logloss: 0.672877
# [4]	valid_0's multi_logloss: 0.601011
# [5]	valid_0's multi_logloss: 0.544059
# [6]	valid_0's multi_logloss: 0.50353
# [7]	valid_0's multi_logloss: 0.468284
# [8]	valid_0's multi_logloss: 0.44211
# [9]	valid_0's multi_logloss: 0.413586
# [10]	valid_0's multi_logloss: 0.385422
# [11]	valid_0's multi_logloss: 0.364586
# [12]	valid_0's multi_logloss: 0.343405
# [13]	valid_0's multi_logloss: 0.325212
# [14]	valid_0's multi_logloss: 0.310943
# [15]	valid_0's multi_logloss: 0.298719
# [16]	valid_0's multi_logloss: 0.285034
# [17]	valid_0's multi_logloss: 0.273576
# [18]	valid_0's multi_logloss: 0.262785
# [19]	valid_0's multi_logloss: 0.253876
# [20]	valid_0's multi_logloss: 0.246443
# [21]	valid_0's multi_logloss: 0.23935
# [22]	valid_0's multi_logloss: 0.233838
# [23]	valid_0's multi_logloss: 0.227211
# [24]	valid_0's multi_logloss: 0.222548
# [25]	valid_0's multi_logloss: 0.217933
# [26]	valid_0's multi_logloss: 0.214522
# [27]	valid_0's multi_logloss: 0.210393
# [28]	valid_0's multi_logloss: 0.207866
# [29]	valid_0's multi_logloss: 0.20379
# [30]	valid_0's multi_logloss: 0.201316
# [31]	valid_0's multi_logloss: 0.198897
# [32]	valid_0's multi_logloss: 0.196274
# [33]	valid_0's multi_logloss: 0.193763
# [34]	valid_0's multi_logloss: 0.191322
# [35]	valid_0's multi_logloss: 0.188626
# [36]	valid_0's multi_logloss: 0.187252
# [37]	valid_0's multi_logloss: 0.186135
# [38]	valid_0's multi_logloss: 0.184647
# [39]	valid_0's multi_logloss: 0.183476
# [40]	valid_0's multi_logloss: 0.182138
# [41]	valid_0's multi_logloss: 0.180961
# [42]	valid_0's multi_logloss: 0.179676
# [43]	valid_0's multi_logloss: 0.178416
# [44]	valid_0's multi_logloss: 0.177003
# [45]	valid_0's multi_logloss: 0.176183
# [46]	valid_0's multi_logloss: 0.175492
# [47]	valid_0's multi_logloss: 0.174903
# [48]	valid_0's multi_logloss: 0.174245
# [49]	valid_0's multi_logloss: 0.173378
# [50]	valid_0's multi_logloss: 0.172474
# [51]	valid_0's multi_logloss: 0.171556
# [52]	valid_0's multi_logloss: 0.170871
# [53]	valid_0's multi_logloss: 0.170059
# [54]	valid_0's multi_logloss: 0.169889
# [55]	valid_0's multi_logloss: 0.16953
# [56]	valid_0's multi_logloss: 0.169127
# [57]	valid_0's multi_logloss: 0.168884
# [58]	valid_0's multi_logloss: 0.168571
# [59]	valid_0's multi_logloss: 0.168191
# [60]	valid_0's multi_logloss: 0.167848
# [61]	valid_0's multi_logloss: 0.167204
# [62]	valid_0's multi_logloss: 0.167006
# [63]	valid_0's multi_logloss: 0.166572
# [64]	valid_0's multi_logloss: 0.166147
# [65]	valid_0's multi_logloss: 0.165827
# [66]	valid_0's multi_logloss: 0.165474
# [67]	valid_0's multi_logloss: 0.165112
# [68]	valid_0's multi_logloss: 0.164784
# [69]	valid_0's multi_logloss: 0.164481
# [70]	valid_0's multi_logloss: 0.164192
# [71]	valid_0's multi_logloss: 0.163955
# [72]	valid_0's multi_logloss: 0.163752
# [73]	valid_0's multi_logloss: 0.163621
# [74]	valid_0's multi_logloss: 0.163346
# [75]	valid_0's multi_logloss: 0.163223
# [76]	valid_0's multi_logloss: 0.162929
# [77]	valid_0's multi_logloss: 0.162811
# [78]	valid_0's multi_logloss: 0.162684
# [79]	valid_0's multi_logloss: 0.162495
# [80]	valid_0's multi_logloss: 0.162396
# [81]	valid_0's multi_logloss: 0.162213
# [82]	valid_0's multi_logloss: 0.161975
# [83]	valid_0's multi_logloss: 0.161819
# [84]	valid_0's multi_logloss: 0.161697
# [85]	valid_0's multi_logloss: 0.161589
# [86]	valid_0's multi_logloss: 0.161532
# [87]	valid_0's multi_logloss: 0.161515
# [88]	valid_0's multi_logloss: 0.161403
# [89]	valid_0's multi_logloss: 0.161359
# [90]	valid_0's multi_logloss: 0.161294
# [91]	valid_0's multi_logloss: 0.16123
# [92]	valid_0's multi_logloss: 0.161102
# [93]	valid_0's multi_logloss: 0.161055
# [94]	valid_0's multi_logloss: 0.160974
# [95]	valid_0's multi_logloss: 0.160927
# [96]	valid_0's multi_logloss: 0.160838
# [97]	valid_0's multi_logloss: 0.160791
# [98]	valid_0's multi_logloss: 0.160768
# [99]	valid_0's multi_logloss: 0.160713
# [100]	valid_0's multi_logloss: 0.160696
# [101]	valid_0's multi_logloss: 0.160671
# [102]	valid_0's multi_logloss: 0.160605
# [103]	valid_0's multi_logloss: 0.160501
# [104]	valid_0's multi_logloss: 0.160456
# [105]	valid_0's multi_logloss: 0.16041
# [106]	valid_0's multi_logloss: 0.160373
# [107]	valid_0's multi_logloss: 0.160352
# [108]	valid_0's multi_logloss: 0.160271
# [109]	valid_0's multi_logloss: 0.160258
# [110]	valid_0's multi_logloss: 0.160247
# [111]	valid_0's multi_logloss: 0.160219
# [112]	valid_0's multi_logloss: 0.160134
# [113]	valid_0's multi_logloss: 0.160154
# [114]	valid_0's multi_logloss: 0.160138
# [115]	valid_0's multi_logloss: 0.160137
# [116]	valid_0's multi_logloss: 0.16011
# [117]	valid_0's multi_logloss: 0.16006
# [118]	valid_0's multi_logloss: 0.160002
# [119]	valid_0's multi_logloss: 0.159959
# [120]	valid_0's multi_logloss: 0.159963
# [121]	valid_0's multi_logloss: 0.159944
# [122]	valid_0's multi_logloss: 0.15989
# [123]	valid_0's multi_logloss: 0.159863
# [124]	valid_0's multi_logloss: 0.159801
# [125]	valid_0's multi_logloss: 0.159802
# [126]	valid_0's multi_logloss: 0.159784
# [127]	valid_0's multi_logloss: 0.159742
# [128]	valid_0's multi_logloss: 0.159731
# [129]	valid_0's multi_logloss: 0.159712
# [130]	valid_0's multi_logloss: 0.159703
# [131]	valid_0's multi_logloss: 0.159703
# [132]	valid_0's multi_logloss: 0.159693
# [133]	valid_0's multi_logloss: 0.159694
# [134]	valid_0's multi_logloss: 0.159671
# [135]	valid_0's multi_logloss: 0.159668
# [136]	valid_0's multi_logloss: 0.159629
# [137]	valid_0's multi_logloss: 0.159595
# [138]	valid_0's multi_logloss: 0.15961
# [139]	valid_0's multi_logloss: 0.159633
# [140]	valid_0's multi_logloss: 0.159629
# [141]	valid_0's multi_logloss: 0.159613
# [142]	valid_0's multi_logloss: 0.159611
# [143]	valid_0's multi_logloss: 0.159591
# [144]	valid_0's multi_logloss: 0.159595
# [145]	valid_0's multi_logloss: 0.159572
# [146]	valid_0's multi_logloss: 0.159555
# [147]	valid_0's multi_logloss: 0.159553
# [148]	valid_0's multi_logloss: 0.159585
# [149]	valid_0's multi_logloss: 0.159608
# [150]	valid_0's multi_logloss: 0.159604
# [151]	valid_0's multi_logloss: 0.159598
# [152]	valid_0's multi_logloss: 0.159596
# [153]	valid_0's multi_logloss: 0.159586
# [154]	valid_0's multi_logloss: 0.159568
# [155]	valid_0's multi_logloss: 0.159562
# [156]	valid_0's multi_logloss: 0.15955
# [157]	valid_0's multi_logloss: 0.159589
# [158]	valid_0's multi_logloss: 0.159594
# [159]	valid_0's multi_logloss: 0.159576
# [160]	valid_0's multi_logloss: 0.159589
# [161]	valid_0's multi_logloss: 0.159576
# [162]	valid_0's multi_logloss: 0.159588
# [163]	valid_0's multi_logloss: 0.159564
# [164]	valid_0's multi_logloss: 0.159583
# [165]	valid_0's multi_logloss: 0.159588
# [166]	valid_0's multi_logloss: 0.159612
# Early stopping, best iteration is:
# [156]	valid_0's multi_logloss: 0.15955

# %%
print(f'{accuracy_score(y, np.argmax(p_val, axis=1)) * 100:.4f}%')
# Out:
# 93.2863%

# %%
print(p_val.shape, p_tst.shape)
# Out:
# (320000, 3) (80000, 3)

# %%
np.savetxt(p_val_file, p_val, fmt='%.6f', delimiter=',')
np.savetxt(p_tst_file, p_tst, fmt='%.6f', delimiter=',')

# %% [markdown]
# ## 피처 중요도 시각화

# %%
imp = pd.DataFrame({'feature': df.columns, 'importance': clf.feature_importances_})
imp = imp.sort_values('importance').set_index('feature')
imp.plot(kind='barh')

# %% [markdown]
# ## 제출 파일 생성

# %%
sub = pd.read_csv(sample_file, index_col=0)
print(sub.shape)
sub.head()
# Out:
# (80000, 1)
#         class
# id
# 320000      0
# 320001      0
# 320002      0
# 320003      0
# 320004      0

# %%
sub[target_col] = np.argmax(p_tst, axis=1)
sub.head()
# Out:
#         class
# id
# 320000      2
# 320001      0
# 320002      2
# 320003      0
# 320004      2

# %%
sub[target_col].value_counts()
# Out:
# 2    41027
# 0    29969
# 1     9004
# Name: class, dtype: int64

# %%
sub.to_csv(sub_file)
